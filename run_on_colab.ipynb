# %%
# Add the directory to sys.path in order for the modules to be available for import
import sys
sys.path.append("/content/DataChum")
sys.path
# Download DataChum repository
# !git clone https://github.com/chrigesch/DataChum
# Change directory to the downloaded folder
# %cd /content/DataChum
# Install all packages
# !pip3 install -r requirements.txt

# %%
import sys
sys.path.append("/content/DataChum")
sys.path
# Change directory to the downloaded folder
# %cd /content/DataChum
# !npm install localtunnel
# Open streamlit application
# !streamlit run index.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Copy & paste the "Endpoint ID" that appears right before "npx: installed"
